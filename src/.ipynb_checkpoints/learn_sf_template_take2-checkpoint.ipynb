# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import audioread
import librosa
import os
# import seaborn as sns

from audio_read import AudioReader

# %%
def half_rectify(n):
    return np.fmax(n, np.zeros_like(n))

# %%
def spectral_flux(spec):
    """
    Computes the spectral flux of a spectrogram
    :param spec: a 2-D array of floats
    :return: a numpy array
    """
    return np.expand_dims(np.sum(np.square(half_rectify(np.absolute(spec[:, 1:]) -
                                         np.absolute(spec[:, :-1]))), 0), axis=0)

# %%
import sklearn.neighbors as nbrs
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier

sample_dirs = ["../audio/samples/onsets/ALFRED/", "../audio/samples/onsets/DANBY/"]

# clf_KNN = nbrs.KNeighborsClassifier(n_neighbors=5)
# clf_SVM = SVC()
# clf_forest = RandomForestClassifier()
clf_SGD = SGDClassifier(loss='log', penalty='l2', verbose=1, fit_intercept=False)

# clfs = [clf_KNN, clf_SVM, clf_forest, clf_SGD]
clfs = [clf_SGD]

# %%
# Audio params

# filename = "../audio/SBI-1_20090915_234016.wav"
# annotation_path = "../annotations/SBI-1_20090915_HAND_LOW_IDaek_EDITED_with_HIGH.txt"
# model_path = "../features/SBI_coefs_41.npy"

# Load audio and compute spectrogram
sr = 24000.0
n_fft = 256 # =win_length
win_length = n_fft
hop_length = 128
hop_size = hop_length/sr # in seconds
win_size = win_length/sr # in seconds
spec_dt = hop_length/sr # in seconds
truncate = 0
# truncate = 40

# Define length of coefficient window
w_length = 5    # let's just use odd numbered values, ok?

# %%
def make_feature(spec, spec_dt, w_length):
#     print spec.shape
    l = spec.shape[1]
    mid = l/2;
    start = mid - np.floor((w_length)/2)
    end = start + w_length
#     print l
    
#     sf = np.square(half_rectify(np.absolute(spec[:, start:end]) -
#                                      np.absolute(spec[:, start-1:end-1])))
    sf = (half_rectify(np.absolute(spec[truncate:, start:end]) -
                                     np.absolute(spec[truncate:, start-1:end-1])))
    return sf.reshape(1, sf.size)

# %%
# plt.figure(figsize=(20,10))
# # plt.imshow(spec)
# # plt.plot(sf)
# plt.imshow(spec[40:, start:end])
# # plt.imshow(spec[40:, start-1:end-1])

# %%
# Train
import random

for sample_dir in sample_dirs:
        d = os.listdir(sample_dir)
#         d = random.shuffle(os.listdir(sample_dir))
#         random.shuffle(d)
#         for f in random.sample(d, len(d)): # randomize
        for f in d:
            if f[-4:] != '.wav':
                continue
            y, _ = librosa.load(sample_dir + f, sr=sr)

            spec = librosa.core.stft(y, n_fft=n_fft, hop_length=hop_length)
            feature = make_feature(spec, spec_dt, w_length)

#             print feature
            if f[0] == 't':
                label = np.asarray([1])
            elif f[0] == 'f':
                label = np.asarray([0])
            else:
                print "BAD FILENAMES!"
                exit()
            print feature.shape
            for clf in clfs:
#                 print feature.shape
#                 print label
#                 print feature[0]
                clf.partial_fit(feature, label, classes=[0,1])
return clfs
# Out:
# (1, 645)
# -- Epoch 1
# Norm: 154.20, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.693147
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 154.05, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 153.89, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 153.74, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 153.59, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 153.43, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 153.28, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 153.13, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 152.98, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 152.83, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 152.67, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 152.52, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 152.37, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 152.22, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 152.07, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 151.92, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 151.77, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 151.62, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 151.47, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 151.33, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 151.18, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 151.03, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 150.88, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 150.73, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 150.59, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 150.44, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 150.29, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 150.15, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 150.00, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 149.86, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 149.71, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 149.56, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 149.42, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 149.27, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 149.13, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 148.99, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 148.84, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 148.70, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 148.56, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 148.41, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 148.27, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 148.13, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.99, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.84, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.70, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.56, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.42, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.28, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.14, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 147.00, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 146.86, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 146.72, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 146.58, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 146.44, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 146.30, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 146.16, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 146.02, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 145.89, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 145.75, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 145.61, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 145.47, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 145.34, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 145.20, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 145.06, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 144.93, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 144.79, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 144.65, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 144.52, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 144.38, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 144.25, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 144.11, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.98, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.84, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.71, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.58, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.44, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.31, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.18, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 143.04, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 142.91, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 142.78, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 142.65, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 142.51, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 142.38, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 142.25, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 142.12, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.99, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.86, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.73, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.60, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.47, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.34, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.21, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 141.08, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.95, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.82, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.69, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.57, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.44, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.31, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.18, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 140.06, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.93, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.80, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.67, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.55, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.42, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.30, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.17, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.05, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.92, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.79, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.67, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.55, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.42, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.30, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.17, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.05, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.93, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.80, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.68, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.56, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.43, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.31, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.19, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.07, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.95, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.82, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.70, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.58, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.46, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.34, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.22, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.10, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.98, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.86, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.74, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.62, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.50, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.38, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.26, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.15, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.03, NNZs: 314, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.91, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.79, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.67, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.56, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.44, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.32, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.20, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 134.09, NNZs: 510, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.97, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.86, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.74, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.62, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.51, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.39, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.28, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.16, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 133.05, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.93, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.82, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.70, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.59, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.48, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.36, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.25, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.13, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 132.02, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.91, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.80, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.68, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.57, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.46, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.35, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.23, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.12, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 131.01, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.90, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.79, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.68, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.57, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.46, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.35, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.24, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.13, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 130.02, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.91, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.80, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.69, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.58, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.47, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.36, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.25, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.15, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 129.04, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.93, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.82, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.72, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.61, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.50, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.39, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.29, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.18, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 128.07, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.97, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.86, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.76, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.65, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.54, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.44, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.33, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.23, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.12, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 127.02, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.91, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.81, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.71, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.60, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.50, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.39, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.29, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.19, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 126.08, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.98, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.88, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.78, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.67, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.57, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.47, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.37, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.26, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.16, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 125.06, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.96, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.86, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.76, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.66, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.56, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.46, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.36, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.26, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.16, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 124.06, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.96, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.86, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.76, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.66, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.56, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.46, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.36, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.26, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.16, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 123.07, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.97, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.87, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.77, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.67, NNZs: 580, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.58, NNZs: 617, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.48, NNZs: 617, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.38, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.28, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.19, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 122.09, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.99, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.90, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.80, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.71, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.61, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.51, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.42, NNZs: 630, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.32, NNZs: 637, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.23, NNZs: 637, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.13, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 121.04, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.94, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.85, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.75, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.66, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.56, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.47, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.38, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.28, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.19, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.09, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 120.00, NNZs: 639, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.91, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.81, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.72, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.63, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.54, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.44, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.35, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.26, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.17, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 119.07, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.98, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.89, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.80, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.71, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.62, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.53, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.43, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.34, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.25, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.16, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 118.07, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.98, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.89, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.80, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.71, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.62, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.53, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.44, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.35, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.26, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.17, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.09, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 117.00, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.91, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.82, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.73, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.64, NNZs: 642, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.55, NNZs: 643, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.47, NNZs: 643, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.38, NNZs: 643, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.29, NNZs: 643, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.20, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.12, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 116.03, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.94, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.85, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.77, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.68, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.59, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.51, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.42, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.33, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.25, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.16, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 115.08, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.99, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.90, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.82, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.73, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.65, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.56, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.48, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.39, NNZs: 644, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.31, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.22, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.14, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 114.05, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.97, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.89, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.80, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.72, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.63, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.55, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.47, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.38, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.30, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.22, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.13, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 113.05, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.97, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.89, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.80, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.72, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.64, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.56, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.47, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.39, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.31, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.23, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.15, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 112.06, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.98, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.90, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.82, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.74, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.66, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.58, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.50, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.42, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.34, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.26, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.18, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.10, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 111.02, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 110.94, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 110.86, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 110.78, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# ...
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.43, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.40, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.36, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.33, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.30, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.27, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.24, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.20, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.17, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.14, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.11, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.08, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.05, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 139.01, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.98, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.95, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.92, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.89, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.85, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.82, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.79, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.76, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.73, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.70, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.66, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.63, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.60, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.57, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.54, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.51, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.47, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.44, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.41, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.38, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.35, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.32, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.29, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.25, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.22, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.19, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.16, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.13, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.10, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.06, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.03, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 138.00, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.97, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.94, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.91, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.88, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.85, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.81, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.78, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.75, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.72, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.69, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.66, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.63, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.60, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.56, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.53, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.50, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.47, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.44, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.41, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.38, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.35, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.32, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.28, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.25, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.22, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.19, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.16, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.13, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.10, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.07, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.04, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 137.01, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.97, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.94, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.91, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.88, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.85, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.82, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.79, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.76, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.73, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.70, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.67, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.64, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.60, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.57, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.54, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.51, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.48, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.45, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.42, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.39, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.36, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.33, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.30, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.27, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.24, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.21, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.18, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.14, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.11, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.08, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.05, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 136.02, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.99, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.96, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.93, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.90, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.87, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.84, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.81, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.78, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.75, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.72, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.69, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.66, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.63, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.60, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.57, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.54, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# (1, 645)
# -- Epoch 1
# Norm: 135.51, NNZs: 645, Bias: 0.000000, T: 1, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# /Users/Fuzz/Documents/Coding/ipykernel/ipykernel/__main__.py:11: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /Users/Fuzz/Documents/Coding/ipykernel/ipykernel/__main__.py:12: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   File "<ipython-input-8-be58c402f2ca>", line 31
#     return clfs
# SyntaxError: 'return' outside function

# %%
model = clfs[0]
print model
print w_length
coefs2 = model.coef_.reshape((n_fft/2 + 1, w_length))
coefs = model.coef_
# np.save(model_path, coefs)
print coefs.shape
plt.imshow((coefs2), interpolation='nearest', aspect='auto', cmap='hot')
# Out:
# SGDClassifier(alpha=0.0001, class_weight=None, epsilon=0.1, eta0=0.0,
#        fit_intercept=False, l1_ratio=0.15, learning_rate='optimal',
#        loss='log', n_iter=5, n_jobs=1, penalty='l2', power_t=0.5,
#        random_state=None, shuffle=False, verbose=1, warm_start=False)
# 5
# (1, 645)

# %%
np.argmax(coefs)
# Out:
# 384

# %%
def make_feature_set(spec, spec_dt, annotation_path, w_length):
    """
    Generates features and labels from spectrogram.
    :param spec: NxM numpy array
    :param spec_dt: float
    :param annotation_path: String
    :param w_length: int
    :return: features, labels
    """
    if annotation_path is not None:
        df = pd.read_csv(annotation_path, header=None, 
            names=['onsets', 'offsets', 'label'], delimiter='\t')
        onsets = np.asarray(df['onsets'])
        offsets = np.asarray(df['offsets'])

    num_features = spec.shape[1]-w_length+1

    # Generate features
    features = [[]] * num_features
    for i in xrange(num_features):
    	features[i] = np.ravel(spec[:, i:i+w_length])

    # Generate labels
    if annotation_path is not None:
        labels = np.zeros(num_features)
#         for on, off in zip(onsets, offsets):
        for on in onsets:
#             center = (on+off)/2
#             start = int(np.round((center-0.100)/spec_dt))
#             finish = int(np.round((center+0.100)/spec_dt))
            start = int(np.round((on-0.100)/spec_dt))
            finish = int(np.round((on+0.100)/spec_dt))
            labels[start:finish+1] = 1
        return np.asarray(features).T, labels

    return np.asarray(features).T

# %%
###### # Evaluate model
test_path = '../audio/NSDNS_20110902_192900.wav'
detection_curve_path = '../detection_functions/NSDNS_SF_54.npy'
# detection_curve_csv = '../detection_functions/NSDNS_SF_52.txt'
# test_path = '../audio/ALFRED_20110924_183200.wav'
# detection_curve_path = '../detection_functions/ALFRED_SF_50_test.npy'

# coefs = np.load(model_path)
# c = coefs.reshape(645,1)

# Iterate through signal by large blocks (constrained by RAM)
duration = None          #seconds
num_hops_per_block = 30000
block_size = hop_size*num_hops_per_block
block_len = num_hops_per_block-w_length+1 # samples

# Preallocate detection curve
det_curve_len = 0
if duration is None:
    with audioread.audio_open(test_path) as f:
        det_curve_len = int(np.floor(f.duration*f.samplerate/(hop_length*num_hops_per_block))*num_hops_per_block)
        print det_curve_len
else:
    det_curve_len = int(np.floor(duration*sr/(hop_length*num_hops_per_block))*num_hops_per_block)
detection_curve = np.zeros((1,det_curve_len))

block_i = 0
done = False

# reader = AudioReader(test_path, sr=sr, channels=1)

print "Starting eval with params duration={}, block_len={}".format(duration, num_hops_per_block)
# f = open(detection_curve_csv, 'w')



while not done:
    print "Testing next block... i={} ".format(block_i) + str(time.clock())
    offset = block_i*block_size
    y, _ = librosa.load(test_path, offset=0, duration=block_size, sr=sr)
    if len(y) < block_size*sr or (duration is not None and offset > duration):
        print "last one!"
        # BAD!!! Throwing out last bit of data
        break
        done = True
#     D = np.abs(librosa.core.stft(y, n_fft=n_fft, hop_length=hop_length))
    D = librosa.core.stft(y, n_fft=n_fft, hop_length=hop_length)

    # Transform frames of spec into vector
    features = np.asarray(make_feature_set(D, spec_dt, annotation_path=None, 
        w_length=w_length))

    # Apply almost all of SF algorithm
    actual_features = np.square(half_rectify(np.absolute(features[:, 1:]) -
                                     np.absolute(features[:, :-1])))
#     actual_features = (half_rectify(np.absolute(features[1:, truncate:]) -
#                                      np.absolute(features[:-1, truncate:])))
    
    # Template detector
    # detection_curve = np.concatenate((detection_curve,features.dot(c)), axis=1)

#     print np.dot(coefs, actual_features).shape
    # Multi-frame SF
#     test_coefs = np.ones_like(coefs)
#     detection_curve = np.concatenate((detection_curve,np.dot(coefs, actual_features)), axis=1)
#     detection_curve = np.concatenate((detection_curve, np.dot(test_coefs, actual_features)), axis=1)
#     print spectral_flux(features).shape
#     detection_curve = np.concatenate((detection_curve, spectral_flux(features)), axis=1)

    detection_curve[0][block_len*block_i:block_len*(block_i+1)] = np.dot(coefs, actual_features)

# Below this line is version that work as hoped
#    detection_curve = np.concatenate((detection_curve, spectral_flux(D)), axis=1)
#     detection_curve = spectral_flux(features)

#     sf_res = spectral_flux(features)
#     test_res = np.dot(test_coefs, actual_features)
#     assert np.all(np.dot(test_coefs, actual_features) == spectral_flux(features))
    
#     f.write(detection_curve.tostring())
    block_i += 1

# np.save(detection_curve_path, detection_curve.T)
# f.close()
print spec_dt
# Out:
# 6600000
# Starting eval with params duration=None, block_len=30000
# Testing next block... i=0 12.046336
# Testing next block... i=1 16.522625
# Testing next block... i=2 20.928345
# Testing next block... i=3 25.358245
# Testing next block... i=4 29.753397
# Testing next block... i=5 33.971416
# Testing next block... i=6 38.217563
# Testing next block... i=7 42.405211
# Testing next block... i=8 46.563814
# Testing next block... i=9 50.637225
# Testing next block... i=10 55.01899
# Testing next block... i=11 59.804915
# Testing next block... i=12 64.149179
# Testing next block... i=13 68.673546
# Testing next block... i=14 72.963508
# Testing next block... i=15 77.204617
# Testing next block... i=16 81.509391
# Testing next block... i=17 85.784161
# Testing next block... i=18 90.068064
# Testing next block... i=19 94.322461
# Testing next block... i=20 98.631367
# Testing next block... i=21 102.887962
# Testing next block... i=22 107.458719
# Testing next block... i=23 111.624146
# Testing next block... i=24 115.831373
# Testing next block... i=25 120.726238
# Testing next block... i=26 124.981109
# Testing next block... i=27 129.477047
# Testing next block... i=28 133.953637
# Testing next block... i=29 138.429957
# Testing next block... i=30 142.822631
# Testing next block... i=31 147.08066
# Testing next block... i=32 151.604956
# Testing next block... i=33 156.257556
# Testing next block... i=34 160.879564
# Testing next block... i=35 165.295997
# Testing next block... i=36 169.498205
# Testing next block... i=37 173.634646
# Testing next block... i=38 177.990063
# Testing next block... i=39 182.096861
# Testing next block... i=40 186.166782
# Testing next block... i=41 190.286341
# Testing next block... i=42 194.562546
# Testing next block... i=43 198.750586
# Testing next block... i=44 202.873805
# Testing next block... i=45 207.005687
# Testing next block... i=46 211.379112
# Testing next block... i=47 215.653387
# Testing next block... i=48 219.778147
# Testing next block... i=49 223.869015
# Testing next block... i=50 227.939169
# Testing next block... i=51 232.498654
# Testing next block... i=52 237.285636
# Testing next block... i=53 241.769467
# Testing next block... i=54 246.269288
# Testing next block... i=55 250.483892
# Testing next block... i=56 254.693309
# Testing next block... i=57 259.275502
# Testing next block... i=58 263.629926
# Testing next block... i=59 267.825818
# Testing next block... i=60 272.025412
# Testing next block... i=61 276.166399
# Testing next block... i=62 280.587295
# Testing next block... i=63 284.812524
# Testing next block... i=64 289.156852
# Testing next block... i=65 293.331648
# Testing next block... i=66 297.454523
# Testing next block... i=67 301.608566
# Testing next block... i=68 305.723223
# Testing next block... i=69 310.185814
# Testing next block... i=70 314.292858
# Testing next block... i=71 318.458555
# Testing next block... i=72 322.595418
# Testing next block... i=73 326.920605
# Testing next block... i=74 331.202997
# Testing next block... i=75 335.320526
# Testing next block... i=76 339.405491
# Testing next block... i=77 343.530309
# Testing next block... i=78 347.627703
# Testing next block... i=79 351.821905
# Testing next block... i=80 356.022681
# Testing next block... i=81 360.313566
# Testing next block... i=82 364.468358
# Testing next block... i=83 368.738394
# Testing next block... i=84 372.983289
# Testing next block... i=85 377.152526
# Testing next block... i=86 381.286779
# Testing next block... i=87 385.79586
# Testing next block... i=88 389.928813
# Testing next block... i=89 394.092273
# Testing next block... i=90 398.270245
# Testing next block... i=91 402.879345
# Testing next block... i=92 407.006547
# Testing next block... i=93 411.098451
# Testing next block... i=94 415.211317
# Testing next block... i=95 419.236269
# Testing next block... i=96 423.364162
# Testing next block... i=97 427.424245
# Testing next block... i=98 431.480442
# Testing next block... i=99 435.601362
# Testing next block... i=100 439.701769
# Testing next block... i=101 443.828608
# Testing next block... i=102 447.860767
# Testing next block... i=103 452.322904
# Testing next block... i=104 456.39426
# Testing next block... i=105 460.441152
# Testing next block... i=106 464.45517
# Testing next block... i=107 468.518605
# Testing next block... i=108 472.555738
# Testing next block... i=109 476.61688
# Testing next block... i=110 480.706862
# Testing next block... i=111 484.74473
# Testing next block... i=112 488.851221
# Testing next block... i=113 492.935023
# Testing next block... i=114 496.97298
# Testing next block... i=115 501.07379
# Testing next block... i=116 505.234972
# Testing next block... i=117 509.300245
# Testing next block... i=118 513.335983
# Testing next block... i=119 517.386663
# Testing next block... i=120 521.51811
# Testing next block... i=121 525.630745
# Testing next block... i=122 529.848139
# Testing next block... i=123 534.016776
# Testing next block... i=124 538.203148
# Testing next block... i=125 542.277333
# Testing next block... i=126 546.62307
# Testing next block... i=127 550.67793
# Testing next block... i=128 554.76567
# Testing next block... i=129 558.864239
# Testing next block... i=130 562.886444
# Testing next block... i=131 566.972702
# Testing next block... i=132 571.091246
# Testing next block... i=133 575.421989
# Testing next block... i=134 579.540113
# Testing next block... i=135 583.627677
# Testing next block... i=136 587.576317
# Testing next block... i=137 591.654472
# Testing next block... i=138 595.733284
# Testing next block... i=139 599.829352
# Testing next block... i=140 604.093495
# Testing next block... i=141 608.261762
# Testing next block... i=142 612.455837
# Testing next block... i=143 616.986823
# Testing next block... i=144 621.183155
# Testing next block... i=145 625.363582
# Testing next block... i=146 629.526445
# Testing next block... i=147 633.84257
# Testing next block... i=148 638.20998
# Testing next block... i=149 643.050228
# Testing next block... i=150 647.385259
# Testing next block... i=151 651.868153
# Testing next block... i=152 656.294893
# Testing next block... i=153 660.442874
# Testing next block... i=154 664.825444
# Testing next block... i=155 669.084604
# Testing next block... i=156 673.44269
# Testing next block... i=157 677.781797
# Testing next block... i=158 682.015159
# Testing next block... i=159 686.31408
# Testing next block... i=160 690.585003
# Testing next block... i=161 694.756203
# Testing next block... i=162 699.181911
# Testing next block... i=163 703.551271
# Testing next block... i=164 708.36917
# Testing next block... i=165 712.86304
# Testing next block... i=166 717.271435
# Testing next block... i=167 721.577948
# Testing next block... i=168 725.698557
# Testing next block... i=169 729.866285
# Testing next block... i=170 734.221965
# Testing next block... i=171 738.38039
# Testing next block... i=172 742.5455
# Testing next block... i=173 746.611513
# Testing next block... i=174 750.74435
# Testing next block... i=175 755.134913
# Testing next block... i=176 759.425251
# Testing next block... i=177 763.611532
# Testing next block... i=178 767.868874
# Testing next block... i=179 772.192868
# Testing next block... i=180 776.470233
# Testing next block... i=181 780.768558
# Testing next block... i=182 784.995564
# Testing next block... i=183 789.045326
# Testing next block... i=184 793.571412
# Testing next block... i=185 797.677852
# Testing next block... i=186 801.800823
# Testing next block... i=187 806.012598
# Testing next block... i=188 810.504942
# Testing next block... i=189 814.629051
# Testing next block... i=190 818.87934
# Testing next block... i=191 823.05246
# Testing next block... i=192 827.115614
# Testing next block... i=193 831.448738
# Testing next block... i=194 835.580271
# Testing next block... i=195 839.745572
# Testing next block... i=196 843.950625
# Testing next block... i=197 848.074228
# Testing next block... i=198 852.132766
# Testing next block... i=199 856.176347
# Testing next block... i=200 860.245544
# Testing next block... i=201 864.285147
# Testing next block... i=202 868.353592
# Testing next block... i=203 872.414023
# Testing next block... i=204 876.630776
# Testing next block... i=205 880.724962
# Testing next block... i=206 884.846252
# Testing next block... i=207 888.818485
# Testing next block... i=208 892.913527
# Testing next block... i=209 896.970219
# Testing next block... i=210 901.006714
# Testing next block... i=211 905.136521
# Testing next block... i=212 909.19516
# Testing next block... i=213 913.347053
# Testing next block... i=214 917.649951
# Testing next block... i=215 921.773939
# Testing next block... i=216 925.915848
# Testing next block... i=217 930.176676
# Testing next block... i=218 934.849171
# Testing next block... i=219 939.079043
# Testing next block... i=220 943.190726
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-865c339ca785> in <module>()
#      64 #     detection_curve = np.concatenate((detection_curve, spectral_flux(features)), axis=1)
#      65
# ---> 66     detection_curve[0][block_len*block_i:block_len*(block_i+1)] = np.dot(coefs, actual_features)
#      67
#      68 # Below this line is version that work as hoped
#
# ValueError: could not broadcast input array from shape (29996) into shape (880)

# %%
# print test_res.shape
# print sf_res.shape

# diff_res = test_res-sf_res
# print np.min(diff_res)
# print np.max(diff_res)
# plt.imshow(diff_res[:,:100])

# %%
print detection_curve.shape
print detection_curve[:10]
# print detection_curve[0,:]

np.save(detection_curve_path, detection_curve[0,:])
# Out:
# (1, 6600000)
# [[ 1.24885559  1.71835628  0.97605014 ...,  0.80543813  0.25914008
#    0.05356066]]

# %%
print detection_curve.shape
print detection_curve[:10]
# Out:
# (1, 6600000)
# [[ 1.24885559  1.71835628  0.97605014 ...,  0.80543813  0.25914008
#    0.05356066]]

# %%
# detection_curve = detection_curve[1:]
# detection_curve -= min(detection_curve)
# detection_curve /= max(detection_curve)
plt.plot(detection_curve)
# onsets = np.nonzero(actual_labels)
# plt.plot([onsets[0],onsets[0]], [-40,40], 'r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-bfb902fa8d16> in <module>()
#       5 # onsets = np.nonzero(actual_labels)
#       6 # plt.plot([onsets[0],onsets[0]], [-40,40], 'r')
# ----> 7 plt.show()
#
# /Library/Python/2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     153     """
#     154     global _show
# --> 155     return _show(*args, **kw)
#     156
#     157
#
# /Users/Fuzz/Documents/Coding/ipykernel/ipykernel/pylab/backend_inline.pyc in show(close)
#      30     try:
#      31         for figure_manager in Gcf.get_all_fig_managers():
# ---> 32             display(figure_manager.canvas.figure)
#      33     finally:
#      34         show._to_draw = []
#
# /Library/Python/2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     157             publish_display_data(data=obj, metadata=metadata)
#     158         else:
# --> 159             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     160             if not format_dict:
#     161                 # nothing to display (e.g. _ipython_display_ took over)
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     173             md = None
#     174             try:
# --> 175                 data = formatter(obj)
#     176             except:
#     177                 # FIXME: log the exception
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     218     """show traceback on failed format call"""
#     219     try:
# --> 220         r = method(self, *args, **kwargs)
#     221     except NotImplementedError:
#     222         # don't warn on NotImplementedErrors
#
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# /Library/Python/2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     205
#     206     if 'png' in formats:
# --> 207         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     208     if 'retina' in formats or 'png2x' in formats:
#     209         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Library/Python/2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     115
#     116     bytes_io = BytesIO()
# --> 117     fig.canvas.print_figure(bytes_io, **kw)
#     118     data = bytes_io.getvalue()
#     119     if fmt == 'svg':
#
# /Library/Python/2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2156                     orientation=orientation,
#    2157                     dryrun=True,
# -> 2158                     **kwargs)
#    2159                 renderer = self.figure._cachedRenderer
#    2160                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Library/Python/2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     519
#     520     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 521         FigureCanvasAgg.draw(self)
#     522         renderer = self.get_renderer()
#     523         original_dpi = renderer.dpi
#
# /Library/Python/2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /Library/Python/2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Library/Python/2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1083         dsu.sort(key=itemgetter(0))
#    1084         for zorder, a, func, args in dsu:
# -> 1085             func(*args)
#    1086
#    1087         renderer.close_group('figure')
#
# /Library/Python/2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Library/Python/2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2108
#    2109         for zorder, a in dsu:
# -> 2110             a.draw(renderer)
#    2111
#    2112         renderer.close_group('axes')
#
# /Library/Python/2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /Library/Python/2.7/site-packages/matplotlib/lines.pyc in draw(self, renderer)
#     713                 funcname = self.drawStyles.get(self._drawstyle, '_draw_lines')
#     714                 drawFunc = getattr(self, funcname)
# --> 715                 drawFunc(renderer, gc, tpath, affine.frozen())
#     716
#     717         if self._marker:
#
# /Library/Python/2.7/site-packages/matplotlib/transforms.pyc in frozen(self)
#    1665
#    1666     def frozen(self):
# -> 1667         return Affine2D(self.get_matrix().copy())
#    1668     frozen.__doc__ = AffineBase.frozen.__doc__
#    1669
#
# /Library/Python/2.7/site-packages/matplotlib/transforms.pyc in __init__(self, matrix, **kwargs)
#    1747         If *matrix* is None, initialize with the identity transform.
#    1748         """
# -> 1749         Affine2DBase.__init__(self, **kwargs)
#    1750         if matrix is None:
#    1751             matrix = np.identity(3)
#
# /Library/Python/2.7/site-packages/matplotlib/transforms.pyc in __init__(self, *args, **kwargs)
#    1592
#    1593     def __init__(self, *args, **kwargs):
# -> 1594         Transform.__init__(self, *args, **kwargs)
#    1595         self._inverted = None
#    1596
#
# /Library/Python/2.7/site-packages/matplotlib/transforms.pyc in __init__(self, shorthand_name)
#      95         # parents are deleted, references from the children won't keep
#      96         # them alive.
# ---> 97         self._parents = WeakValueDictionary()
#      98
#      99         # TransformNodes start out as invalid until their values are
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/weakref.pyc in __init__(self, *args, **kw)
#      46
#      47     def __init__(self, *args, **kw):
# ---> 48         def remove(wr, selfref=ref(self)):
#      49             self = selfref()
#      50             if self is not None:
#
# KeyboardInterrupt:

# %%
np.argmax(detection_curve)
# Out:
# 24266

# %%
actual_labels[6280:6295]
np.nonzero(actual_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d202bc8a466b> in <module>()
# ----> 1 actual_labels[6280:6295]
#       2 np.nonzero(actual_labels)
#
# NameError: name 'actual_labels' is not defined
